# %%
import numpy as np
import pandas as pd
import pickle

# %% [markdown]
# ## After 1 iteration with one word

# %%
# using test-iters.py with 1 iteration
test_vs_pred_file1 = "one_word/preds_vs_labels_iters1.tsv"
tp1 = pd.read_table(test_vs_pred_file1)

# %%
tp1[tp1["same_diff"] == 'DIFF']
# Out:
#           filename same_diff  pred_on_orig   pred_on_adv      target  \
# 0         five.wav      DIFF          five         magin        five
# 1    universal.wav      DIFF  tht universa           fro   universal
# 2      imagine.wav      DIFF         magin      amiericl     imagine
# 3      horizon.wav      DIFF    ther rizen           her     horizon
# 4   reflection.wav      DIFF    reflect on          stor  reflection
# 5         peas.wav      DIFF         piece       plastic        peas
# 6         frog.wav      DIFF          foro  the universa        frog
# 7      miracle.wav      DIFF      americol         ardsh     miracle
# 8          her.wav      DIFF           her        tolken         her
# 9        store.wav      DIFF          stor        ray bo       store
# 10     rainbow.wav      DIFF        ray bo          iove     rainbow
# 11       token.wav      DIFF         token    reflection       token
# 12     horizon.wav      DIFF    ther rizen         piece     horizon
# ...

# %%
# using test.py which is built in for just one iteration
test_vs_pred_file5 = "one_word/preds_vs_labels_iters5.tsv"
tp5 = pd.read_table(test_vs_pred_file5)

# %%
tp5[tp5["same_diff"] == 'DIFF']
# Out:
#           filename same_diff  pred_on_orig   pred_on_adv      target  \
# 0        above.wav      DIFF          iofe        uabove       above
# 3    universal.wav      DIFF  tht universa  the universa   universal
# 4        token.wav      DIFF         token        tolken       token
# 5      imagine.wav      DIFF         magin     imadgined     imagine
# 6        store.wav      DIFF          stor         store       store
# 7   reflection.wav      DIFF    reflect on    reflection  reflection
# 8      miracle.wav      DIFF      americol     amierical     miracle
# 9      rainbow.wav      DIFF        ray bo         raybo     rainbow
# 10        frog.wav      DIFF          foro            fr        frog
# 11     plastic.wav      DIFF        plasti       plastic     plastic
# 12     horizon.wav      DIFF    ther rizen    ther rison     horizon
# 13        arch.wav      DIFF        ardshu          arhp        arch
# 14  phenomenon.wav      DIFF   a nomenents    a nomenens  phenomenon
# ...

# %%
# using test.py which is built in for just one iteration
test_vs_pred_file10 = "one_word/preds_vs_labels_iters10.tsv"
tp10 = pd.read_table(test_vs_pred_file10)

# %%
tp10[tp10["same_diff"] == 'DIFF']
# Out:
#           filename same_diff  pred_on_orig   pred_on_adv      target  \
# 0        above.wav      DIFF          iofe         above       above
# 1          bob.wav      DIFF           bob           bup         bob
# 2   reflection.wav      DIFF    reflect on    reflection  reflection
# 3   phenomenon.wav      DIFF   a nomenents     anomenons  phenomenon
# 4        token.wav      DIFF         token         hoken       token
# 6      imagine.wav      DIFF         magin     imadgined     imagine
# 7      miracle.wav      DIFF      americol     amierical     miracle
# 8         arch.wav      DIFF        ardshu         arhep        arch
# 9      plastic.wav      DIFF        plasti       plastic     plastic
# 10   universal.wav      DIFF  tht universa  the universa   universal
# 11     horizon.wav      DIFF    ther rizen   their rison     horizon
# 12        frog.wav      DIFF          foro            fr        frog
# 13        peas.wav      DIFF         piece         peace        peas
# ...

# %%
adv1_ex_file = open("one_word/adv_x_iters1.npy")
orig1_ex_file = open("one_word/orig_x_iters1.npy")

orig1 = pickle.load(orig1_ex_file)
adv1 = pickle.load(adv1_ex_file)

# %%
print orig1[0].shape
print adv1[0].shape
# Out:
# (16, 29, 20)
# (16, 29, 20)

# %% [markdown]
# ## After 1 iteration on VCTK

# %%
adv2_ex_file = open("iterative_results/adv_x1.npy")
orig2_ex_file = open("iterative_results/orig_x1.npy")

orig2 = pickle.load(orig2_ex_file)
adv2 = pickle.load(adv2_ex_file)

# %%
adv2[0].shape
# Out:
# (158, 20)

# %%
test_vs_pred2_file = "preds_vs_labels1.tsv"
tp2 = pd.read_table(test_vs_pred2_file)

# %%
tp2[tp2['same_diff'] == 'DIFF']
# Out:
#          filename same_diff  \
# 0    p271_088.wav      DIFF
# 1    p271_104.wav      DIFF
# 3    p271_094.wav      DIFF
# 6    p271_127.wav      DIFF
# 11   p271_114.wav      DIFF
# 15   p271_121.wav      DIFF
# 18   p271_132.wav      DIFF
# 19   p271_090.wav      DIFF
# 23   p271_120.wav      DIFF
# 24   p271_119.wav      DIFF
# 27   p271_113.wav      DIFF
# 31   p271_101.wav      DIFF
# 34   p271_112.wav      DIFF
# 36   p271_134.wav      DIFF
# 38   p271_122.wav      DIFF
# 45   p271_135.wav      DIFF
# 47   p271_141.wav      DIFF
# 48   p271_146.wav      DIFF
# 57   p271_140.wav      DIFF
# 58   p271_143.wav      DIFF
# 60   p271_107.wav      DIFF
# 63   p271_151.wav      DIFF
# 64   p271_153.wav      DIFF
# 67   p271_158.wav      DIFF
# 70   p271_200.wav      DIFF
# 71   p271_160.wav      DIFF
# 72   p271_173.wav      DIFF
# 74   p271_152.wav      DIFF
# 75   p271_176.wav      DIFF
# 77   p271_170.wav      DIFF
# 78   p271_168.wav      DIFF
# 84   p271_178.wav      DIFF
# ...

# %%
adv1_ex_file = open("adv_x_iters1.npy")
orig1_ex_file = open("orig_x_iters1.npy")

orig1 = pickle.load(orig1_ex_file)
adv1 = pickle.load(adv1_ex_file)

# %%
test_vs_pred1_file = "preds_vs_labels_iters1.tsv"
tp1 = pd.read_table(test_vs_pred1_file)

tp1[tp1['same_diff'] == 'DIFF']
# Out:
#          filename same_diff  \
# 0    p271_088.wav      DIFF
# 1    p271_113.wav      DIFF
# 2    p271_134.wav      DIFF
# 3    p271_115.wav      DIFF
# 4    p271_095.wav      DIFF
# 6    p271_090.wav      DIFF
# 10   p271_140.wav      DIFF
# 14   p271_121.wav      DIFF
# 17   p271_101.wav      DIFF
# 19   p271_117.wav      DIFF
# 24   p271_132.wav      DIFF
# 25   p271_094.wav      DIFF
# 27   p271_141.wav      DIFF
# 28   p271_104.wav      DIFF
# 41   p271_127.wav      DIFF
# 43   p271_136.wav      DIFF
# 44   p271_100.wav      DIFF
# 45   p271_143.wav      DIFF
# 50   p271_124.wav      DIFF
# 55   p271_146.wav      DIFF
# 56   p271_122.wav      DIFF
# 58   p271_112.wav      DIFF
# 60   p271_148.wav      DIFF
# 63   p271_151.wav      DIFF
# 65   p271_170.wav      DIFF
# 66   p271_153.wav      DIFF
# 67   p271_154.wav      DIFF
# 68   p271_152.wav      DIFF
# 70   p271_158.wav      DIFF
# 73   p271_160.wav      DIFF
# 76   p271_161.wav      DIFF
# 77   p271_159.wav      DIFF
# ...

# %%
tp2[tp2['same_diff'] == 'SAME'][:5]
# Out:
# Empty DataFrame
# Columns: [filename, same_diff, pred_on_orig, pred_on_adv, target, num_pred_on_orig, num_pred_on_adv, num_target]
# Index: []

# %% [markdown]
# ## After 5 iterations on VCTK

# %%
adv5_ex_file = open("iterative_results/adv_x_iters5.npy")
orig5_ex_file = open("iterative_results/orig_x_iters5.npy")

# %%
orig5 = pickle.load(orig5_ex_file)
adv5 = pickle.load(adv5_ex_file)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-9d72c4ce8c0f> in <module>()
# ----> 1 orig5 = pickle.load(orig5_ex_file)
#       2 adv5 = pickle.load(adv5_ex_file)
#
# /usr/lib/python2.7/pickle.pyc in load(file)
#    1376
#    1377 def load(file):
# -> 1378     return Unpickler(file).load()
#    1379
#    1380 def loads(str):
#
# /usr/lib/python2.7/pickle.pyc in load(self)
#     856             while 1:
#     857                 key = read(1)
# --> 858                 dispatch[key](self)
#     859         except _Stop, stopinst:
#     860             return stopinst.value
#
# KeyError: '\x93'

# %%
print orig5.shape
print adv5.shape
# Out:
# (16, 159, 20)
# (16, 161, 20)

# %%
test_vs_pred5_file = "iterative_results/preds_vs_labels_iters5.tsv"

# %%
tp5 = pd.read_table(test_vs_pred5_file)

# %%
tp5[:5]
# Out:
#        filename same_diff                     pred_on_orig  \
# 0  p271_097.wav      DIFF             then came the crunch
# 1  p271_136.wav      DIFF                       is that it
# 2  p271_101.wav      DIFF  i wish i had puton a briger tye
# 3  p271_147.wav      DIFF                      i was awful
# 4  p271_116.wav      DIFF                it was the eities
#
#                                          pred_on_adv  \
# 0                                what wil hapen then
# 1                                    it is home gron
# 2                                         i was dead
# 3  if people are jenuin then the problem is now s...
# 4                                  she reflects a it
#
#                                target  \
# 0                then came the crunch
# 1                          is that it
# 2  i wish i had put on a brighter tie
# 3                         i was awful
# 4                 it was the eighties
#
# ...

# %% [markdown]
# ## 10 Iterations

# %%
adv10_ex_file = open("iterative_results/adv_x_iters10.npy")
orig10_ex_file = open("iterative_results/orig_x_iters10.npy")

# %%
orig10 = pickle.load(orig10_ex_file)
adv10 = pickle.load(adv10_ex_file)

# %%
test_vs_pred10_file = "preds_vs_labels_iters10.tsv"
tp10 = pd.read_table(test_vs_pred10_file)

# %%
tp10[:5]
# Out:
#        filename same_diff                                       pred_on_orig  \
# 0  p271_100.wav      DIFF                               they are no devorced
# 1  p271_115.wav      DIFF               he leaves a wife a son ander dauhter
# 2  p271_142.wav      DIFF         sudenly the fir park side were in dhisaray
# 3  p271_103.wav      DIFF        however we have not come to any conclusions
# 4  p271_122.wav      DIFF  that was the weston to be learned from the yea...
#
#                                          pred_on_adv  \
# 0  the proporsals are to be debated on monday by ...
# 1                                         is that it
# 2  alice the girl was said by doctors to be in go...
# 3                                  she reflects a it
# 4                                      i am a nactor
#
#                                               target  \
# 0                              they are now divorced
# 1              he leaves a wife a son and a daughter
# ...
