# %%
from InverseMfcc import InverseMfcc
import librosa
import numpy as np

# %%
y, sr = librosa.load('audios/p310_363.wav', mono=True, sr=None)
imfcc = InverseMfcc(y, sr)
imfcc.transform()

# %%
"""
Parameters:
sr: sampling rate (default to provided file)
num_mfcc: how many MFCC to include as features (default to 20)
include_deltas: boolean to include higher-order mfcc features
n_mel_recon: 128 (not sure of effect of changing this yet)
n_fft_recon: 2048 (not sure of effect of changing this yet)
"""

imfcc.play_original()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
imfcc.play_transformed()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#### Increase MFCCs and try again ####
imfcc.modify_parameters(num_mfcc=150, include_deltas=True)
imfcc.transform()
imfcc.play_transformed()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
