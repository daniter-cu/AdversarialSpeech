# %%
import numpy as np

# %%
before = np.load("before.npy")
after = np.load("after.npy")

# %%
after.shape
# Out:
# (1, 53, 13)

# %%
N_MFCC=100
HOP_LENGTH = 500





# Load input audio.
filename = '../audios/orig_48.wav'
y, sr = librosa.load(filename)
print(sr)


# Calculate mfccs.
Y = librosa.stft(y)
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=N_MFCC, hop_length=HOP_LENGTH)
print 'mfccs shape: {}'.format(mfccs.shape)


# Build reconstruction mappings.
n_mfcc = mfccs.shape[0]
n_mel = 128
dctm = librosa.filters.dct(n_mfcc, n_mel)
n_fft = 2048
mel_basis = librosa.filters.mel(sr, n_fft)
# Empirical scaling of channels to get ~flat amplitude mapping.
bin_scaling = 1.0 / np.maximum(0.0005, np.sum(np.dot(mel_basis.T, mel_basis), axis=0))


# Reconstruct the approximate STFT squared-magnitude from the MFCCs.
recon_stft = bin_scaling[:, np.newaxis] * np.dot(mel_basis.T, 
        invlogamplitude(np.dot(dctm.T, mfccs)))


# Impose reconstructed magnitude on white noise STFT.
excitation = np.random.randn(y.shape[0])
E = librosa.stft(excitation, hop_length=HOP_LENGTH)
recon = librosa.istft(E / np.abs(E) * np.sqrt(recon_stft))
print recon
# Listen to the reconstruction
Audio(recon, rate=sr)
# Out:
# 22050
# mfccs shape: (100, 391)
# [ 0.00389424  0.00393603  0.00328781 ...,  0.00096959 -0.00091683
#  -0.00285599]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Load input audio.
filename = '../audios/orig_48.wav'
y, sr = librosa.load(filename)
print(sr)


# Calculate mfccs.
Y = librosa.stft(y)
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=N_MFCC, hop_length=HOP_LENGTH)
print 'mfccs shape: {}'.format(mfccs.shape)
# Out:
# 22050
# mfccs shape: (100, 391)

# %% [markdown]
# # Reconstruct from MFCCs originial and noisy

# %%
import librosa
import numpy as np
from IPython.lib.display import Audio

# %%
def invlogamplitude(S):
    '''librosa.logamplitude is actually 10*log10, so invert that.'''
    return 10.0 ** (S / 10.0)

# %%
mfccs = after.transpose((0, 2, 1))[0]
print mfccs.shape

# Build reconstruction mappings.
n_mfcc = mfccs.shape[0]
n_mel = 128
dctm = librosa.filters.dct(n_mfcc, n_mel)
n_fft = 2048
mel_basis = librosa.filters.mel(sr, n_fft)
# Empirical scaling of channels to get ~flat amplitude mapping.
bin_scaling = 1.0 / np.maximum(0.0005, np.sum(np.dot(mel_basis.T, mel_basis), axis=0))


# Reconstruct the approximate STFT squared-magnitude from the MFCCs.
recon_stft = bin_scaling[:, np.newaxis] * np.dot(mel_basis.T, 
        invlogamplitude(np.dot(dctm.T, mfccs)))


# Impose reconstructed magnitude on white noise STFT.
excitation = np.random.randn(mfccs.shape[1])
E = librosa.stft(excitation, hop_length=HOP_LENGTH)
recon = librosa.istft(E / np.abs(E) * np.sqrt(recon_stft))
print recon
# Listen to the reconstruction
Audio(recon, rate=sr)
# Out:
# (13, 53)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6d21bc1e2177> in <module>()
#       7 dctm = librosa.filters.dct(n_mfcc, n_mel)
#       8 n_fft = 2048
# ----> 9 mel_basis = librosa.filters.mel(sr, n_fft)
#      10 # Empirical scaling of channels to get ~flat amplitude mapping.
#      11 bin_scaling = 1.0 / np.maximum(0.0005, np.sum(np.dot(mel_basis.T, mel_basis), axis=0))
#
# NameError: name 'sr' is not defined
